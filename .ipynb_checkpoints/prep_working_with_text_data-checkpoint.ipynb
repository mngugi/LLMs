# %%
from importlib_metadata import version

print("torch version: ", version("torch"))
print("tiktoken:", version("tiktoken"))
# Out:
# torch version:  2.10.0
# tiktoken: 0.12.0

# %%
import os
import requests

if not os.path.exists("the-verdict.txt"):
    url = (
        "https://raw.githubusercontent.com/rasbt/"
        "LLMs-from-scratch/main/ch02/01_main-chapter-code/"
        "the-verdict.txt"
    )
    file_path = "the-verdict.txt"

    response = requests.get(url, timeout=30)
    response.raise_for_status()
    with open(file_path, "wb") as f:
        f.write(response.content)

# %%
# !pip install --upgrade certifi
# Out:
# Requirement already satisfied: certifi in /home/sizma86/anaconda3/lib/python3.13/site-packages (2026.1.4)
# Collecting certifi
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
# Installing collected packages: certifi
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2026.1.4
#     Uninstalling certifi-2026.1.4:
#       Successfully uninstalled certifi-2026.1.4
# Successfully installed certifi-2026.2.25
